# %%
import numpy as np 
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
movies.dropna(inplace=True)

# %%
movies = movies[['rating','genre','name','director','writer','star','country']]

# %%
movies.head()
# Out:
#   rating      genre                                            name  \
# 0      R      Drama                                     The Shining
# 1      R  Adventure                                 The Blue Lagoon
# 2     PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3     PG     Comedy                                       Airplane!
# 4      R     Comedy                                      Caddyshack
#
#           director                   writer            star         country
# 0  Stanley Kubrick             Stephen King  Jack Nicholson  United Kingdom
# 1   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields   United States
# 2   Irvin Kershner           Leigh Brackett     Mark Hamill   United States
# 3     Jim Abrahams             Jim Abrahams     Robert Hays   United States
# 4     Harold Ramis       Brian Doyle-Murray     Chevy Chase   United States

# %%
movies['tag']=movies['rating']+movies['genre']+movies['director']+movies['writer']+movies['star']+movies['country']

# %%
movies.head()
# Out:
#   rating      genre                                            name  \
# 0      R      Drama                                     The Shining
# 1      R  Adventure                                 The Blue Lagoon
# 2     PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3     PG     Comedy                                       Airplane!
# 4      R     Comedy                                      Caddyshack
#
#           director                   writer            star         country  \
# 0  Stanley Kubrick             Stephen King  Jack Nicholson  United Kingdom
# 1   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields   United States
# 2   Irvin Kershner           Leigh Brackett     Mark Hamill   United States
# 3     Jim Abrahams             Jim Abrahams     Robert Hays   United States
# 4     Harold Ramis       Brian Doyle-Murray     Chevy Chase   United States
#
#                                                  tag
# ...

# %%
movies.drop(columns=['tag'])
# Out:
#          rating      genre                                            name  \
# 0             R      Drama                                     The Shining
# 1             R  Adventure                                 The Blue Lagoon
# 2            PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3            PG     Comedy                                       Airplane!
# 4             R     Comedy                                      Caddyshack
# ...         ...        ...                                             ...
# 7648          R     Action                               Bad Boys for Life
# 7649         PG     Action                              Sonic the Hedgehog
# 7650         PG  Adventure                                        Dolittle
# 7651         PG  Adventure                            The Call of the Wild
# 7652  Not Rated     Action                               The Eight Hundred
#
#              director                   writer               star  \
# ...

# %%
movies['tag'] = movies['rating'].map(str) + movies['genre'].map(str) + movies['director'].map(str)+movies['writer'].map(str)+movies['star'].map(str) +movies['country'].map(str)

# %%
movies.head()
# Out:
#   rating      genre                                            name  \
# 0      R      Drama                                     The Shining
# 1      R  Adventure                                 The Blue Lagoon
# 2     PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3     PG     Comedy                                       Airplane!
# 4      R     Comedy                                      Caddyshack
#
#           director                   writer            star         country  \
# 0  Stanley Kubrick             Stephen King  Jack Nicholson  United Kingdom
# 1   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields   United States
# 2   Irvin Kershner           Leigh Brackett     Mark Hamill   United States
# 3     Jim Abrahams             Jim Abrahams     Robert Hays   United States
# 4     Harold Ramis       Brian Doyle-Murray     Chevy Chase   United States
#
#                                                  tag
# ...

# %%
movies.drop(columns=['tag'])
# Out:
#          rating      genre                                            name  \
# 0             R      Drama                                     The Shining
# 1             R  Adventure                                 The Blue Lagoon
# 2            PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3            PG     Comedy                                       Airplane!
# 4             R     Comedy                                      Caddyshack
# ...         ...        ...                                             ...
# 7648          R     Action                               Bad Boys for Life
# 7649         PG     Action                              Sonic the Hedgehog
# 7650         PG  Adventure                                        Dolittle
# 7651         PG  Adventure                            The Call of the Wild
# 7652  Not Rated     Action                               The Eight Hundred
#
#              director                   writer               star  \
# ...

# %%
movies['tag'] = movies['rating'].map(str) +' '+ movies['genre'].map(str)+' ' + movies['director'].map(str)+' '+movies['writer'].map(str)+' '+movies['star'].map(str)+' ' +movies['country'].map(str)

# %%
movies.head()
# Out:
#   rating      genre                                            name  \
# 0      R      Drama                                     The Shining
# 1      R  Adventure                                 The Blue Lagoon
# 2     PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3     PG     Comedy                                       Airplane!
# 4      R     Comedy                                      Caddyshack
#
#           director                   writer            star         country  \
# 0  Stanley Kubrick             Stephen King  Jack Nicholson  United Kingdom
# 1   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields   United States
# 2   Irvin Kershner           Leigh Brackett     Mark Hamill   United States
# 3     Jim Abrahams             Jim Abrahams     Robert Hays   United States
# 4     Harold Ramis       Brian Doyle-Murray     Chevy Chase   United States
#
#                                                  tag
# ...

# %%
movies['write']=movies['writer']

# %%
movies.head()
# Out:
#   rating      genre                                            name  \
# 0      R      Drama                                     The Shining
# 1      R  Adventure                                 The Blue Lagoon
# 2     PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3     PG     Comedy                                       Airplane!
# 4      R     Comedy                                      Caddyshack
#
#           director                   writer            star         country  \
# 0  Stanley Kubrick             Stephen King  Jack Nicholson  United Kingdom
# 1   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields   United States
# 2   Irvin Kershner           Leigh Brackett     Mark Hamill   United States
# 3     Jim Abrahams             Jim Abrahams     Robert Hays   United States
# 4     Harold Ramis       Brian Doyle-Murray     Chevy Chase   United States
#
#                                                  tag                    write
# ...

# %%
movies['write'] = movies['write'].str.strip()

# %%
movies.head()
# Out:
#   rating      genre                                            name  \
# 0      R      Drama                                     The Shining
# 1      R  Adventure                                 The Blue Lagoon
# 2     PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3     PG     Comedy                                       Airplane!
# 4      R     Comedy                                      Caddyshack
#
#           director                   writer            star         country  \
# 0  Stanley Kubrick             Stephen King  Jack Nicholson  United Kingdom
# 1   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields   United States
# 2   Irvin Kershner           Leigh Brackett     Mark Hamill   United States
# 3     Jim Abrahams             Jim Abrahams     Robert Hays   United States
# 4     Harold Ramis       Brian Doyle-Murray     Chevy Chase   United States
#
#                                                  tag                    write
# ...

# %%
movies['write'] = movies['write'].str.replace(' ', '')

# %%
movies.head()
# Out:
#   rating      genre                                            name  \
# 0      R      Drama                                     The Shining
# 1      R  Adventure                                 The Blue Lagoon
# 2     PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3     PG     Comedy                                       Airplane!
# 4      R     Comedy                                      Caddyshack
#
#           director                   writer            star         country  \
# 0  Stanley Kubrick             Stephen King  Jack Nicholson  United Kingdom
# 1   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields   United States
# 2   Irvin Kershner           Leigh Brackett     Mark Hamill   United States
# 3     Jim Abrahams             Jim Abrahams     Robert Hays   United States
# 4     Harold Ramis       Brian Doyle-Murray     Chevy Chase   United States
#
#                                                  tag                 write
# ...

# %%
movies['writer'] = movies['writer'].str.replace(' ', '')
movies['director'] = movies['director'].str.replace(' ', '')
movies['star'] = movies['star'].str.replace(' ', '')
movies['country'] = movies['country'].str.replace(' ', '')

# %%
movies.head()
# Out:
#   rating      genre                                            name  \
# 0      R      Drama                                     The Shining
# 1      R  Adventure                                 The Blue Lagoon
# 2     PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3     PG     Comedy                                       Airplane!
# 4      R     Comedy                                      Caddyshack
#
#          director                writer           star        country  \
# 0  StanleyKubrick           StephenKing  JackNicholson  UnitedKingdom
# 1   RandalKleiser  HenryDeVereStacpoole  BrookeShields   UnitedStates
# 2   IrvinKershner         LeighBrackett     MarkHamill   UnitedStates
# 3     JimAbrahams           JimAbrahams     RobertHays   UnitedStates
# 4     HaroldRamis     BrianDoyle-Murray     ChevyChase   UnitedStates
#
#                                                  tag                 write
# ...

# %%
movies.drop(columns=['tag'])
# Out:
#          rating      genre                                            name  \
# 0             R      Drama                                     The Shining
# 1             R  Adventure                                 The Blue Lagoon
# 2            PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3            PG     Comedy                                       Airplane!
# 4             R     Comedy                                      Caddyshack
# ...         ...        ...                                             ...
# 7648          R     Action                               Bad Boys for Life
# 7649         PG     Action                              Sonic the Hedgehog
# 7650         PG  Adventure                                        Dolittle
# 7651         PG  Adventure                            The Call of the Wild
# 7652  Not Rated     Action                               The Eight Hundred
#
# ...

# %%
movies['tag'] = movies['rating'].map(str) +' '+ movies['genre'].map(str)+' ' + movies['director'].map(str)+' '+movies['writer'].map(str)+' '+movies['star'].map(str)+' ' +movies['country'].map(str)

# %%
movies.drop(columns=['write'])
# Out:
#          rating      genre                                            name  \
# 0             R      Drama                                     The Shining
# 1             R  Adventure                                 The Blue Lagoon
# 2            PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3            PG     Comedy                                       Airplane!
# 4             R     Comedy                                      Caddyshack
# ...         ...        ...                                             ...
# 7648          R     Action                               Bad Boys for Life
# 7649         PG     Action                              Sonic the Hedgehog
# 7650         PG  Adventure                                        Dolittle
# 7651         PG  Adventure                            The Call of the Wild
# 7652  Not Rated     Action                               The Eight Hundred
#
# ...

# %%
movies.drop(columns=['writer','director','star','genre','rating','country','write'])
# Out:
#                                                 name  \
# 0                                        The Shining
# 1                                    The Blue Lagoon
# 2     Star Wars: Episode V - The Empire Strikes Back
# 3                                          Airplane!
# 4                                         Caddyshack
# ...                                              ...
# 7648                               Bad Boys for Life
# 7649                              Sonic the Hedgehog
# 7650                                        Dolittle
# 7651                            The Call of the Wild
# 7652                               The Eight Hundred
#
#                                                     tag                 write
# 0     R Drama StanleyKubrick StephenKing JackNichols...           StephenKing
# 1     R Adventure RandalKleiser HenryDeVereStacpoole...  HenryDeVereStacpoole
# 2     PG Action IrvinKershner LeighBrackett MarkHami...         LeighBrackett
# ...

# %%
movies.drop(columns=['write'])
# Out:
#          rating      genre                                            name  \
# 0             R      Drama                                     The Shining
# 1             R  Adventure                                 The Blue Lagoon
# 2            PG     Action  Star Wars: Episode V - The Empire Strikes Back
# 3            PG     Comedy                                       Airplane!
# 4             R     Comedy                                      Caddyshack
# ...         ...        ...                                             ...
# 7648          R     Action                               Bad Boys for Life
# 7649         PG     Action                              Sonic the Hedgehog
# 7650         PG  Adventure                                        Dolittle
# 7651         PG  Adventure                            The Call of the Wild
# 7652  Not Rated     Action                               The Eight Hundred
#
# ...

# %%
movies.drop(columns=['writer','director','star','genre','rating','country','write'])
# Out:
#                                                 name  \
# 0                                        The Shining
# 1                                    The Blue Lagoon
# 2     Star Wars: Episode V - The Empire Strikes Back
# 3                                          Airplane!
# 4                                         Caddyshack
# ...                                              ...
# 7648                               Bad Boys for Life
# 7649                              Sonic the Hedgehog
# 7650                                        Dolittle
# 7651                            The Call of the Wild
# 7652                               The Eight Hundred
#
#                                                     tag
# 0     R Drama StanleyKubrick StephenKing JackNichols...
# 1     R Adventure RandalKleiser HenryDeVereStacpoole...
# 2     PG Action IrvinKershner LeighBrackett MarkHami...
# 3     PG Comedy JimAbrahams JimAbrahams RobertHays U...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 vector = cv.fit_transform(new['tags']).toarray()
#
# NameError: name 'new' is not defined

# %%
movies=movies.drop(columns=['writer','director','star','genre','rating','country','write'])

# %%
movies.head()
# Out:
#                                              name  \
# 0                                     The Shining
# 1                                 The Blue Lagoon
# 2  Star Wars: Episode V - The Empire Strikes Back
# 3                                       Airplane!
# 4                                      Caddyshack
#
#                                                  tag
# 0  R Drama StanleyKubrick StephenKing JackNichols...
# 1  R Adventure RandalKleiser HenryDeVereStacpoole...
# 2  PG Action IrvinKershner LeighBrackett MarkHami...
# 3  PG Comedy JimAbrahams JimAbrahams RobertHays U...
# 4  R Comedy HaroldRamis BrianDoyle-Murray ChevyCh...

# %%
vector = cv.fit_transform(movies['tag']).toarray()

# %%
vector.shape
# Out:
# (5421, 1000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.        , 0.40824829, ..., 0.5       , 0.35355339,
#         0.        ],
#        [0.        , 0.40824829, 1.        , ..., 0.40824829, 0.28867513,
#         0.33333333],
#        ...,
#        [0.        , 0.5       , 0.40824829, ..., 1.        , 0.35355339,
#         0.        ],
#        [0.        , 0.35355339, 0.28867513, ..., 0.35355339, 1.        ,
#         0.        ],
#        [0.        , 0.        , 0.33333333, ..., 0.        , 0.        ,
#         1.        ]])

# %%
movies.head()
# Out:
#                                              name  \
# 0                                     The Shining
# 1                                 The Blue Lagoon
# 2  Star Wars: Episode V - The Empire Strikes Back
# 3                                       Airplane!
# 4                                      Caddyshack
#
#                                                  tag
# 0  R Drama StanleyKubrick StephenKing JackNichols...
# 1  R Adventure RandalKleiser HenryDeVereStacpoole...
# 2  PG Action IrvinKershner LeighBrackett MarkHami...
# 3  PG Comedy JimAbrahams JimAbrahams RobertHays U...
# 4  R Comedy HaroldRamis BrianDoyle-Murray ChevyCh...

# %%
movies.shape
# Out:
# (5421, 2)

# %%
movies[movies['name'] == 'The Shining'].index[0]
# Out:
# 0

# %%
movies[movies['name'] == 'The Blue Lagoon'].index[0]
# Out:
# 1

# %%
def recommend(movie):
    index = movies[movies['name'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(movies.iloc[i[0]].title)

# %%
recommend('The Shining')
# Out:
# Track 29
# Apartment Zero
# The Secret Garden
# Angels and Insects
# Jude

# %%
movies.head()
# Out:
#                                              name  \
# 0                                     The Shining
# 1                                 The Blue Lagoon
# 2  Star Wars: Episode V - The Empire Strikes Back
# 3                                       Airplane!
# 4                                      Caddyshack
#
#                                                  tag
# 0  R Drama StanleyKubrick StephenKing JackNichols...
# 1  R Adventure RandalKleiser HenryDeVereStacpoole...
# 2  PG Action IrvinKershner LeighBrackett MarkHami...
# 3  PG Comedy JimAbrahams JimAbrahams RobertHays U...
# 4  R Comedy HaroldRamis BrianDoyle-Murray ChevyCh...

# %%
movies.shape
# Out:
# (5421, 2)

# %%
movies['title']=movies['name']

# %%
movies=movies.drop(columns=['name'])

# %%
movies.head()
# Out:
#                                                  tag  \
# 0  R Drama StanleyKubrick StephenKing JackNichols...
# 1  R Adventure RandalKleiser HenryDeVereStacpoole...
# 2  PG Action IrvinKershner LeighBrackett MarkHami...
# 3  PG Comedy JimAbrahams JimAbrahams RobertHays U...
# 4  R Comedy HaroldRamis BrianDoyle-Murray ChevyCh...
#
#                                             title
# 0                                     The Shining
# 1                                 The Blue Lagoon
# 2  Star Wars: Episode V - The Empire Strikes Back
# 3                                       Airplane!
# 4                                      Caddyshack

# %%
movies['name']=movies['title']

# %%
import pickle

# %%
pickle.dump(movies.to_dict(),open('movie_dict.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
